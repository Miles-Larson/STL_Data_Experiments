# %%
notes = {'A':[], 
'A#':[], 
'B':[], 
'C':[], 
'C#':[], 
'D':[], 
'D#':[], 
'E':[], 
'F':[], 
'F#':[], 
'G':[], 
'G#':[], 
 }

# %%
#Add Midi records for each note
notes['A'].append(9)
notes['A'].append(21)
notes['A'].append(33)
notes['A'].append(45)
notes['A'].append(57)
notes['A'].append(69)
notes['A'].append(81)
notes['A'].append(93)
notes['A'].append(105)
notes['A'].append(117)
notes['A#'].append(10)
notes['A#'].append(22)
notes['A#'].append(34)
notes['A#'].append(46)
notes['A#'].append(58)
notes['A#'].append(70)
notes['A#'].append(82)
notes['A#'].append(94)
notes['A#'].append(106)
notes['A#'].append(118)
notes['B'].append(11)
notes['B'].append(23)
notes['B'].append(35)
notes['B'].append(47)
notes['B'].append(59)
notes['B'].append(71)
notes['B'].append(83)
notes['B'].append(95)
notes['B'].append(107)
notes['B'].append(119)
notes['C'].append(0)
notes['C'].append(12)
notes['C'].append(24)
notes['C'].append(36)
notes['C'].append(48)
notes['C'].append(60)
notes['C'].append(72)
notes['C'].append(84)
notes['C'].append(96)
notes['C'].append(108)
notes['C'].append(120)
notes['C#'].append(1)
notes['C#'].append(13)
notes['C#'].append(25)
notes['C#'].append(37)
notes['C#'].append(49)
notes['C#'].append(61)
notes['C#'].append(73)
notes['C#'].append(85)
notes['C#'].append(97)
notes['C#'].append(109)
notes['C#'].append(121)
notes['D'].append(2)
notes['D'].append(14)
notes['D'].append(26)
notes['D'].append(38)
notes['D'].append(50)
notes['D'].append(62)
notes['D'].append(74)
notes['D'].append(86)
notes['D'].append(98)
notes['D'].append(110)
notes['D'].append(122)
notes['D#'].append(3)
notes['D#'].append(15)
notes['D#'].append(27)
notes['D#'].append(39)
notes['D#'].append(51)
notes['D#'].append(63)
notes['D#'].append(75)
notes['D#'].append(87)
notes['D#'].append(99)
notes['D#'].append(111)
notes['D#'].append(123)
notes['E'].append(4)
notes['E'].append(16)
notes['E'].append(28)
notes['E'].append(40)
notes['E'].append(52)
notes['E'].append(64)
notes['E'].append(76)
notes['E'].append(88)
notes['E'].append(100)
notes['E'].append(112)
notes['E'].append(124)
notes['F'].append(5)
notes['F'].append(17)
notes['F'].append(29)
notes['F'].append(41)
notes['F'].append(53)
notes['F'].append(65)
notes['F'].append(77)
notes['F'].append(89)
notes['F'].append(101)
notes['F'].append(113)
notes['F'].append(125)
notes['F#'].append(6)
notes['F#'].append(18)
notes['F#'].append(30)
notes['F#'].append(42)
notes['F#'].append(54)
notes['F#'].append(66)
notes['F#'].append(78)
notes['F#'].append(90)
notes['F#'].append(102)
notes['F#'].append(114)
notes['F#'].append(126)
notes['G'].append(7)
notes['G'].append(19)
notes['G'].append(31)
notes['G'].append(43)
notes['G'].append(55)
notes['G'].append(67)
notes['G'].append(79)
notes['G'].append(91)
notes['G'].append(103)
notes['G'].append(115)
notes['G'].append(127)
notes['G#'].append(8)
notes['G#'].append(20)
notes['G#'].append(32)
notes['G#'].append(44)
notes['G#'].append(56)
notes['G#'].append(68)
notes['G#'].append(80)
notes['G#'].append(92)
notes['G#'].append(104)
notes['G#'].append(116)

notes
# Out:
# {'A': [9, 21, 33, 45, 57, 69, 81, 93, 105, 117],
#  'A#': [10, 22, 34, 46, 58, 70, 82, 94, 106, 118],
#  'B': [11, 23, 35, 47, 59, 71, 83, 95, 107, 119],
#  'C': [0, 12, 24, 36, 48, 60, 72, 84, 96, 108, 120],
#  'C#': [1, 13, 25, 37, 49, 61, 73, 85, 97, 109, 121],
#  'D': [2, 14, 26, 38, 50, 62, 74, 86, 98, 110, 122],
#  'D#': [3, 15, 27, 39, 51, 63, 75, 87, 99, 111, 123],
#  'E': [4, 16, 28, 40, 52, 64, 76, 88, 100, 112, 124],
#  'F': [5, 17, 29, 41, 53, 65, 77, 89, 101, 113, 125],
#  'F#': [6, 18, 30, 42, 54, 66, 78, 90, 102, 114, 126],
#  'G': [7, 19, 31, 43, 55, 67, 79, 91, 103, 115, 127],
#  'G#': [8, 20, 32, 44, 56, 68, 80, 92, 104, 116]}

# %%
#Add flats

notes.update( {'Ab': notes['G#']})
notes.update( {'Bb': notes['A#']})
notes.update( {'Db': notes['C#']})
notes.update( {'Eb': notes['D#']})
notes.update( {'Gb': notes['F#']})

notes
# Out:
# {'A': [9, 21, 33, 45, 57, 69, 81, 93, 105, 117],
#  'A#': [10, 22, 34, 46, 58, 70, 82, 94, 106, 118],
#  'B': [11, 23, 35, 47, 59, 71, 83, 95, 107, 119],
#  'C': [0, 12, 24, 36, 48, 60, 72, 84, 96, 108, 120],
#  'C#': [1, 13, 25, 37, 49, 61, 73, 85, 97, 109, 121],
#  'D': [2, 14, 26, 38, 50, 62, 74, 86, 98, 110, 122],
#  'D#': [3, 15, 27, 39, 51, 63, 75, 87, 99, 111, 123],
#  'E': [4, 16, 28, 40, 52, 64, 76, 88, 100, 112, 124],
#  'F': [5, 17, 29, 41, 53, 65, 77, 89, 101, 113, 125],
#  'F#': [6, 18, 30, 42, 54, 66, 78, 90, 102, 114, 126],
#  'G': [7, 19, 31, 43, 55, 67, 79, 91, 103, 115, 127],
#  'G#': [8, 20, 32, 44, 56, 68, 80, 92, 104, 116],
#  'Ab': [8, 20, 32, 44, 56, 68, 80, 92, 104, 116],
#  'Bb': [10, 22, 34, 46, 58, 70, 82, 94, 106, 118],
#  'Db': [1, 13, 25, 37, 49, 61, 73, 85, 97, 109, 121],
#  'Eb': [3, 15, 27, 39, 51, 63, 75, 87, 99, 111, 123],
#  'Gb': [6, 18, 30, 42, 54, 66, 78, 90, 102, 114, 126]}

# %%
#Add the keys & notes within each key

scales = {}

scales.update({'C':['C','D','E','F','G','A','B']})
scales.update({'G':['G','A','B','C','D','E','F#']})
scales.update({'D':['D','E','F#','G','A','B','C#']})
scales.update({'A':['A','B','C#','D','E','F#','G#']})
scales.update({'E':['E','F#','G#','A','B','C#','D#']})
scales.update({'B':['B','C#','D#','E','F#','G#','D#']})
scales.update({'F#':['F#','G#','A#','B','C#','D#','F']})
scales.update({'C#':['C#','D#','E#','F#','G#','A#','B#']})
scales.update({'F':['F','G','A','A#','C','D','E']})
scales.update({'Bb':['A#','C','D','D#','F','G','A']})

# %%
#TODO: Develop a way to generate time signatures
#Add time signatures

# %%
#mido is used to read and write midi files, winsound can play sounds by hertz input
import mido, winsound
#Pygame is used to synthesize and play midi tracks
import pygame
#datetime will be used to timestamp midi files for progress tracking
import io, datetime, random

# %%
audio_file = mido.MidiFile() 
audio_track = audio_file.add_track('Amazing')

def new_selections():
    global choose_scale, note_options
    choose_scale = random.choice(list(scales.keys()))
    note_options = []
    for i in scales[choose_scale]:
        for x in notes[i]:
            note_options.append(x)
    window_floor = random.randrange(start=1,stop=128)
    window_ceiling = random.randrange(start=window_floor,stop=128)
    note_options = [int(y) for y in note_options  if int(y) > window_floor and int(y) < window_ceiling ]
    if len(note_options) == 0:
        new_selections()
    else:
        print(note_options)
    return note_options

def select_notes_to_play(allowable_notes, phrase_length):
    for i in range(phrase_length):
        random.choice(note_options)
    return 1



def build_midi_section(phrase:object):
    for i in range(phrase.phrase_length):
        midi_message = mido.Message('note_on')
        #midi_message = midi_message.copy(note=(random.randrange(start=0,stop=128)))
        midi_message = midi_message.copy(note=(phrase.play_notes[i]))
        midi_message = midi_message.copy(channel=(phrase.channel_l[i]))
        midi_message = midi_message.copy(velocity=(phrase.velocity_l[i]))
        midi_message = midi_message.copy(time=(phrase.time_l[i]))
        audio_track.append(midi_message)
    return audio_track

class phrase:
    def __init__(self, phrase_length:int, note_selection:list ):
        self.phrase_length:int = phrase_length
        self.note_selection = note_selection
        self.play_notes = []
        self.velocity_l = []
        self.time_l = []
        self.channel_l = []

        for i in range(self.phrase_length):
            self.play_notes.append(random.choice(self.note_selection))
            self.velocity_l.append(random.randrange(start=0,stop=100))
            self.time_l.append(random.randrange(start=0,stop=140))
            self.channel_l.append(random.randrange(start=0,stop=15))
        
    def new_volicity(self):
        self.velocity_l = []
        for i in range(self.phrase_length):
            self.velocity_l.append(random.randrange(start=0,stop=100))
        return self

    def new_time(self):
        self.time_l = []
        for i in range(self.phrase_length):
            self.time_l.append(random.randrange(start=0,stop=140))
        return self


        
    def new_channel(self):
        self.channel_l = []
        for i in range(self.phrase_length):
            self.channel_l.append(random.randrange(start=0,stop=15))
        return self

# %%
phrase_1 = phrase(20, new_selections())
phrase_2 = phrase(15, new_selections())



audio_track = build_midi_section(phrase_1)
audio_track = build_midi_section(phrase_2)
audio_track = build_midi_section(phrase_1.new_time())

audio_file.save('new_song.mid')


print(audio_file)
pygame.init()
pygame.mixer.music.load(r"new_song.mid")
pygame.mixer.music.play()
# Out:
# [91, 93]
# [66, 56, 68, 58, 70, 59, 71, 61, 73, 63, 65]
# MidiFile(type=1, ticks_per_beat=480, tracks=[
#   MidiTrack([
#     MetaMessage('track_name', name='Amazing', time=0),
#     Message('note_on', channel=2, note=93, velocity=46, time=1221),
#     Message('note_on', channel=2, note=91, velocity=5, time=1182),
#     Message('note_on', channel=11, note=91, velocity=96, time=348),
#     Message('note_on', channel=14, note=91, velocity=21, time=1083),
#     Message('note_on', channel=2, note=93, velocity=47, time=1005),
#     Message('note_on', channel=4, note=91, velocity=22, time=256),
#     Message('note_on', channel=13, note=93, velocity=61, time=589),
#     Message('note_on', channel=7, note=93, velocity=87, time=1117),
#     Message('note_on', channel=1, note=93, velocity=73, time=701),
#     Message('note_on', channel=9, note=93, velocity=28, time=38),
#     Message('note_on', channel=2, note=91, velocity=37, time=1005),
# ...

# %%
notes
# Out:
# {'A': [9, 21, 33, 45, 57, 69, 81, 93, 105, 117],
#  'A#': [10, 22, 34, 46, 58, 70, 82, 94, 106, 118],
#  'B': [11, 23, 35, 47, 59, 71, 83, 95, 107, 119],
#  'C': [0, 12, 24, 36, 48, 60, 72, 84, 96, 108, 120],
#  'C#': [1, 13, 25, 37, 49, 61, 73, 85, 97, 109, 121],
#  'D': [2, 14, 26, 38, 50, 62, 74, 86, 98, 110, 122],
#  'D#': [3, 15, 27, 39, 51, 63, 75, 87, 99, 111, 123],
#  'E': [4, 16, 28, 40, 52, 64, 76, 88, 100, 112, 124],
#  'F': [5, 17, 29, 41, 53, 65, 77, 89, 101, 113, 125],
#  'F#': [6, 18, 30, 42, 54, 66, 78, 90, 102, 114, 126],
#  'G': [7, 19, 31, 43, 55, 67, 79, 91, 103, 115, 127],
#  'G#': [8, 20, 32, 44, 56, 68, 80, 92, 104, 116],
#  'Ab': [8, 20, 32, 44, 56, 68, 80, 92, 104, 116],
#  'Bb': [10, 22, 34, 46, 58, 70, 82, 94, 106, 118],
#  'Db': [1, 13, 25, 37, 49, 61, 73, 85, 97, 109, 121],
#  'Eb': [3, 15, 27, 39, 51, 63, 75, 87, 99, 111, 123],
#  'Gb': [6, 18, 30, 42, 54, 66, 78, 90, 102, 114, 126]}

# %%
dog = [i for i in notes.keys()]
print(dog)
# Out:
# ['A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'Ab', 'Bb', 'Db', 'Eb', 'Gb']
